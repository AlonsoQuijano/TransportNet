# %%
import pandas as pd
import numpy as np
import data_handler as dh
import model as md
import time
import matplotlib.pyplot as plt
from matplotlib import rc
import pickle

# %%
import importlib
importlib.reload(dh)
importlib.reload(md)
# Out:
# <module 'model' from '/home/mikhail/Education/Semester_11/TransportNet/Stable Dynamic & Beckman/model.py'>

# %%
import numba
numba.__version__
# Out:
# '0.53.1'

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
from platform import python_version
print('python', python_version())
print('numpy', np.__version__)
print('pandas', pd.__version__)
import graph_tool
print('graph_tool', graph_tool.__version__)
# Out:
# /usr/bin/python3
# 3.6.9 (default, Jan 26 2021, 15:33:00)
# [GCC 8.4.0]
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)
# python 3.6.9
# numpy 1.19.5
# pandas 1.1.4
# graph_tool 2.43 (commit 9d41331e, Wed Jul 7 15:32:52 2021 +0200)

# %% [markdown]
# # Beckman model paradox
# $\rho = 1$
# $\mu = 1$

# %%
beckmann_paradox_save = 'beckmann_paradox_results/'

# %%
net_name = 'BeckmanParadox_net.tntp'
trips_name = 'BeckmanParadox_trips.tntp'

MU = 1
RHO = 1

handler = dh.DataHandler()
graph_data = handler.GetGraphData(net_name, columns = ['init_node', 'term_node', 'capacity', 'free_flow_time'])
graph_correspondences, total_od_flow = handler.GetGraphCorrespondences(trips_name)

no_tax_model = md.Model(graph_data, graph_correspondences, 
                        total_od_flow, mu = MU, rho = RHO)

tax_model = md.ModelWithTaxes(graph_data, graph_correspondences, 
                              total_od_flow, mu = MU, rho = RHO)

graph_data['graph_table'].head()
# Out:
#    init_node  init_node_thru  term_node  term_node_thru      capacity  \
# 0          1            True          2            True  1.000000e-01
# 1          1            True          3            True  1.000000e+20
# 2          2            True          4            True  1.000000e+20
# 3          3            True          4            True  1.000000e-01
# 4          2            True          3            True  1.000000e+20
#
#    free_flow_time
# 0           0.001
# 1          45.000
# 2          45.000
# 3           0.001
# 4           0.001

# %%
max_iter = 50000

solver_kwargs = {'eps_abs': 0.3,
                 'max_iter': max_iter, 'stop_crit': 'dual_gap',
                 'verbose' : True, 'verbose_step': 2000, 'save_history' : True}

print('No tax calculation')
tic = time.time()
no_tax_result = no_tax_model.find_equilibrium(solver_name = 'wda', solver_kwargs = solver_kwargs)
toc = time.time()
print('\tElapsed time: {:.0f} sec'.format(toc - tic))

print('Tax calculation')
tic = time.time()
tax_result = tax_model.find_equilibrium(solver_name = 'wda', solver_kwargs = solver_kwargs)
toc = time.time()
print('\tElapsed time: {:.0f} sec'.format(toc - tic))
# Out:
# No tax calculation
# Composite optimization...
# Oracles created...
# Weighted dual averages method...
# Primal_init = 160012
# Dual_init = -12
# Duality_gap_init = 160000
#
# Iterations number: 2000
# Primal_func_value = 160012
# Dual_func_value = -159700
# Duality_gap = 311.989
# Duality_gap / Duality_gap_init = 0.00194993
#
# Iterations number: 4000
# Primal_func_value = 160012
# Dual_func_value = -159849
# Duality_gap = 163.465
# Duality_gap / Duality_gap_init = 0.00102166
#
# Iterations number: 6000
# Primal_func_value = 160012
# Dual_func_value = -159901
# Duality_gap = 111.42
# Duality_gap / Duality_gap_init = 0.000696375
#
# Iterations number: 8000
# Primal_func_value = 160012
# Dual_func_value = -159927
# Duality_gap = 84.7236
# Duality_gap / Duality_gap_init = 0.000529523
#
# Iterations number: 10000
# Primal_func_value = 160012
# Dual_func_value = -159944
# Duality_gap = 68.438
# Duality_gap / Duality_gap_init = 0.000427738
#
# Iterations number: 12000
# Primal_func_value = 160012
# Dual_func_value = -159955
# Duality_gap = 57.4501
# Duality_gap / Duality_gap_init = 0.000359063
#
# Iterations number: 14000
# Primal_func_value = 160012
# Dual_func_value = -159962
# Duality_gap = 49.5288
# Duality_gap / Duality_gap_init = 0.000309555
#
# Iterations number: 16000
# Primal_func_value = 160012
# Dual_func_value = -159968
# Duality_gap = 43.5436
# Duality_gap / Duality_gap_init = 0.000272148
#
# Iterations number: 18000
# Primal_func_value = 160012
# Dual_func_value = -159973
# Duality_gap = 38.8598
# Duality_gap / Duality_gap_init = 0.000242874
#
# Iterations number: 20000
# Primal_func_value = 160012
# Dual_func_value = -159977
# Duality_gap = 35.0932
# Duality_gap / Duality_gap_init = 0.000219333
#
# Iterations number: 22000
# Primal_func_value = 160012
# Dual_func_value = -159980
# Duality_gap = 31.9975
# Duality_gap / Duality_gap_init = 0.000199985
#
# Iterations number: 24000
# Primal_func_value = 160012
# Dual_func_value = -159983
# Duality_gap = 29.4077
# Duality_gap / Duality_gap_init = 0.000183798
#
# Iterations number: 26000
# Primal_func_value = 160012
# Dual_func_value = -159985
# Duality_gap = 27.2088
# Duality_gap / Duality_gap_init = 0.000170055
#
# Iterations number: 28000
# Primal_func_value = 160012
# Dual_func_value = -159987
# Duality_gap = 25.3181
# Duality_gap / Duality_gap_init = 0.000158238
#
# Iterations number: 30000
# Primal_func_value = 160012
# Dual_func_value = -159988
# Duality_gap = 23.6749
# Duality_gap / Duality_gap_init = 0.000147968
#
# Iterations number: 32000
# Primal_func_value = 160012
# Dual_func_value = -159990
# Duality_gap = 22.2334
# Duality_gap / Duality_gap_init = 0.000138959
#
# Iterations number: 34000
# Primal_func_value = 160012
# Dual_func_value = -159991
# Duality_gap = 20.9586
# Duality_gap / Duality_gap_init = 0.000130991
#
# Iterations number: 36000
# Primal_func_value = 160012
# Dual_func_value = -159992
# Duality_gap = 19.823
# Duality_gap / Duality_gap_init = 0.000123894
#
# Iterations number: 38000
# Primal_func_value = 160012
# Dual_func_value = -159993
# Duality_gap = 18.8049
# Duality_gap / Duality_gap_init = 0.000117531
#
# Iterations number: 40000
# Primal_func_value = 160012
# Dual_func_value = -159994
# Duality_gap = 17.887
# Duality_gap / Duality_gap_init = 0.000111794
#
# Iterations number: 42000
# Primal_func_value = 160012
# Dual_func_value = -159995
# Duality_gap = 17.0551
# Duality_gap / Duality_gap_init = 0.000106594
#
# Iterations number: 44000
# Primal_func_value = 160012
# Dual_func_value = -159996
# Duality_gap = 16.2976
# Duality_gap / Duality_gap_init = 0.00010186
#
# Iterations number: 46000
# Primal_func_value = 160012
# Dual_func_value = -159996
# Duality_gap = 15.6049
# Duality_gap / Duality_gap_init = 9.75307e-05
#
# Iterations number: 48000
# Primal_func_value = 160012
# Dual_func_value = -159997
# Duality_gap = 14.9691
# Duality_gap / Duality_gap_init = 9.35568e-05
#
# Iterations number: 50000
# Primal_func_value = 160012
# Dual_func_value = -159998
# Duality_gap = 14.3834
# Duality_gap / Duality_gap_init = 8.98961e-05
#
# Result: iterations number exceeded
# Total iters: 50000
# Primal_func_value = 160012
# Dual_func_value = -159998
# Duality_gap = 14.3834
# Duality_gap / Duality_gap_init = 8.98961e-05
# Oracle elapsed time: 22 sec
# 	Elapsed time: 31 sec
# Tax calculation
# Composite optimization...
# Oracles created...
# Weighted dual averages method...
# Primal_init = 320012
# Dual_init = -12
# Duality_gap_init = 320000
#
# Iterations number: 2000
# Primal_func_value = 258927
# Dual_func_value = -258620
# Duality_gap = 306.977
# Duality_gap / Duality_gap_init = 0.000959302
#
# Iterations number: 4000
# Primal_func_value = 258841
# Dual_func_value = -258677
# Duality_gap = 163.333
# Duality_gap / Duality_gap_init = 0.000510415
#
# Iterations number: 6000
# Primal_func_value = 258812
# Dual_func_value = -258700
# Duality_gap = 112.479
# Duality_gap / Duality_gap_init = 0.000351497
#
# Iterations number: 8000
# Primal_func_value = 258798
# Dual_func_value = -258712
# Duality_gap = 85.5695
# Duality_gap / Duality_gap_init = 0.000267405
#
# Iterations number: 10000
# Primal_func_value = 258789
# Dual_func_value = -258720
# Duality_gap = 69.123
# Duality_gap / Duality_gap_init = 0.000216009
#
# Iterations number: 12000
# Primal_func_value = 258784
# Dual_func_value = -258726
# Duality_gap = 57.9914
# Duality_gap / Duality_gap_init = 0.000181223
#
# Iterations number: 14000
# Primal_func_value = 258779
# Dual_func_value = -258730
# Duality_gap = 49.689
# Duality_gap / Duality_gap_init = 0.000155278
#
# Iterations number: 16000
# Primal_func_value = 258776
# Dual_func_value = -258733
# Duality_gap = 43.4474
# Duality_gap / Duality_gap_init = 0.000135773
#
# Iterations number: 18000
# Primal_func_value = 258774
# Dual_func_value = -258735
# Duality_gap = 38.5396
# Duality_gap / Duality_gap_init = 0.000120436
#
# Iterations number: 20000
# Primal_func_value = 258772
# Dual_func_value = -258737
# Duality_gap = 34.5815
# Duality_gap / Duality_gap_init = 0.000108067
#
# Iterations number: 22000
# Primal_func_value = 258770
# Dual_func_value = -258739
# Duality_gap = 31.294
# Duality_gap / Duality_gap_init = 9.77939e-05
#
# Iterations number: 24000
# Primal_func_value = 258769
# Dual_func_value = -258741
# Duality_gap = 28.5912
# Duality_gap / Duality_gap_init = 8.93476e-05
#
# Iterations number: 26000
# Primal_func_value = 258768
# Dual_func_value = -258742
# Duality_gap = 26.2553
# Duality_gap / Duality_gap_init = 8.20478e-05
#
# Iterations number: 28000
# Primal_func_value = 258767
# Dual_func_value = -258743
# Duality_gap = 24.211
# Duality_gap / Duality_gap_init = 7.56595e-05
#
# Iterations number: 30000
# Primal_func_value = 258766
# Dual_func_value = -258744
# Duality_gap = 22.4045
# Duality_gap / Duality_gap_init = 7.00141e-05
#
# Iterations number: 32000
# Primal_func_value = 258766
# Dual_func_value = -258745
# Duality_gap = 20.9063
# Duality_gap / Duality_gap_init = 6.53321e-05
#
# Iterations number: 34000
# Primal_func_value = 258765
# Dual_func_value = -258745
# Duality_gap = 19.5174
# Duality_gap / Duality_gap_init = 6.09918e-05
#
# Iterations number: 36000
# Primal_func_value = 258764
# Dual_func_value = -258746
# Duality_gap = 18.3495
# Duality_gap / Duality_gap_init = 5.73422e-05
#
# Iterations number: 38000
# Primal_func_value = 258764
# Dual_func_value = -258747
# Duality_gap = 17.2837
# Duality_gap / Duality_gap_init = 5.40114e-05
#
# Iterations number: 40000
# Primal_func_value = 258764
# Dual_func_value = -258747
# Duality_gap = 16.341
# Duality_gap / Duality_gap_init = 5.10655e-05
#
# Iterations number: 42000
# Primal_func_value = 258763
# Dual_func_value = -258748
# Duality_gap = 15.4684
# Duality_gap / Duality_gap_init = 4.83386e-05
#
# Iterations number: 44000
# Primal_func_value = 258763
# Dual_func_value = -258748
# Duality_gap = 14.7189
# Duality_gap / Duality_gap_init = 4.59966e-05
#
# Iterations number: 46000
# Primal_func_value = 258762
# Dual_func_value = -258748
# Duality_gap = 13.9861
# Duality_gap / Duality_gap_init = 4.37067e-05
#
# Iterations number: 48000
# Primal_func_value = 258762
# Dual_func_value = -258749
# Duality_gap = 13.352
# Duality_gap / Duality_gap_init = 4.17251e-05
#
# Iterations number: 50000
# Primal_func_value = 258762
# Dual_func_value = -258749
# Duality_gap = 12.7765
# Duality_gap / Duality_gap_init = 3.99267e-05
#
# Result: iterations number exceeded
# Total iters: 50000
# Primal_func_value = 258762
# Dual_func_value = -258749
# Duality_gap = 12.7765
# Duality_gap / Duality_gap_init = 3.99267e-05
# Oracle elapsed time: 23 sec
# 	Elapsed time: 31 sec

# %%
def anarchy_cost(tax_result, no_tax_result):
    tax_t = tax_result['times']
    tax_f = tax_result['flows']
    tax_vals = tax_result['taxes']
    no_tax_t = no_tax_result['times']
    no_tax_f = no_tax_result['flows']
    
    tax_total = np.dot(tax_t, tax_f)
    no_tax_total = np.dot(no_tax_t, no_tax_f)
    print("Tax flows:", *tax_f)
    print("No tax flows:", *no_tax_f)
    print("Tax total time:\t\t", tax_total)
    print("No tax total time:\t", no_tax_total)
    print("Anarchy price:\t\t", no_tax_total / tax_total)

anarchy_cost(tax_result, no_tax_result)
# Out:
# Tax flows: 2268.3503453839166 1731.6496546196058 1731.6496546196047 2268.3503453839035 536.7006907650039
# No tax flows: 3999.9999999975835 -0.0 -0.0 3999.9999999975835 3999.9999999975835
# Tax total time:		 257087.26600295116
# No tax total time:	 316977.9666898615
# Anarchy price:		 1.2329586432578221

# %%
tax_result['times']
# Out:
# array([2.23138893e+01, 4.50000000e+01, 4.50000000e+01, 2.23168974e+01,
#        1.00000000e-03])

# %% [markdown]
# # DELETE CODE BELOW!
